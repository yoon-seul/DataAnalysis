# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings(action='ignore')
plt.rcParams["figure.figsize"] = (10,5)

# %%
data=pd.read_csv("hotel_booking.csv")

# %%
data.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  customer_type  \
# 0                        0                     0       2  ...      Transient
# ...

# %% [markdown]
# <li> lead_time : Number of days that elapsed between the entering date of the booking into the PMS and the arrival date.</li>

# %%
data.columns
# Out:
# Index(['hotel', 'is_canceled', 'lead_time', 'arrival_date_year',
#        'arrival_date_month', 'arrival_date_week_number',
#        'arrival_date_day_of_month', 'stays_in_weekend_nights',
#        'stays_in_week_nights', 'adults', 'children', 'babies', 'meal',
#        'country', 'market_segment', 'distribution_channel',
#        'is_repeated_guest', 'previous_cancellations',
#        'previous_bookings_not_canceled', 'reserved_room_type',
#        'assigned_room_type', 'booking_changes', 'deposit_type', 'agent',
#        'company', 'days_in_waiting_list', 'customer_type', 'adr',
#        'required_car_parking_spaces', 'total_of_special_requests',
#        'reservation_status', 'reservation_status_date', 'name', 'email',
#        'phone-number', 'credit_card'],
#       dtype='object')

# %%
data.drop(['company','name','email','phone-number','credit_card'],axis=1,inplace=True)

# %%
data.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  \
# 0                        0                     0       2  ...
# ...

# %%
plt.subplot(1,2,1)
plt.pie(data['hotel'].value_counts(),labels=['City Hotel','Resort Hotel'],autopct='%.1f%%')
plt.subplot(1,2,2)
plt.pie(data['is_canceled'].value_counts(),labels=[0,1],autopct='%.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x181ddfef2e0>,
# ...
#  [Text(-0.4355420495755465, 1.0101005509609093, '0'),
#   Text(0.4355420495755469, -1.0101005509609091, '1')],
#  [Text(-0.2375683906775708, 0.5509639368877687, '63.0%'),
#   Text(0.237568390677571, -0.5509639368877685, '37.0%')])

# %%
sns.distplot(data['lead_time'],color='navy')
# Out:
# <AxesSubplot:xlabel='lead_time', ylabel='Density'>

# %%
plt.subplot(1,2,1)
sns.countplot(data['arrival_date_year'],palette='Blues')
plt.subplot(1,2,2)
plt.xticks(rotation=-45)
sns.countplot(data['arrival_date_month'])
# Out:
# <AxesSubplot:xlabel='arrival_date_month', ylabel='count'>

# %%
plt.xticks(rotation=-45)
sns.countplot(data['arrival_date_week_number'])
# Out:
# <AxesSubplot:xlabel='arrival_date_week_number', ylabel='count'>

# %%
plt.subplot(1,2,1)
sns.countplot(data['stays_in_weekend_nights'])
plt.subplot(1,2,2)
sns.countplot(data['stays_in_week_nights'])
# Out:
# <AxesSubplot:xlabel='stays_in_week_nights', ylabel='count'>

# %%
plt.figure(figsize=(15,5))
plt.subplot(1,3,1)
sns.countplot(data['adults'])
plt.subplot(1,3,2)
sns.countplot(data['children'])
plt.subplot(1,3,3)
sns.countplot(data['babies'])
# Out:
# <AxesSubplot:xlabel='babies', ylabel='count'>

# %%
plt.pie(data['meal'].value_counts(),labels=['BB','HB','SC','Undefined','FB'],autopct='%.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x181de8f4370>,
# ...
#  [Text(-0.8323489200839225, 0.7191628989562298, 'BB'),
#   Text(0.5524963068325438, -0.9511823331708804, 'HB'),
#   Text(1.0199901030372185, -0.4118497173801685, 'SC'),
#   Text(1.09708977274818, -0.07996268211701422, 'Undefined'),
#   Text(1.099757494115253, -0.023096626102945154, 'FB')],
#  [Text(-0.45400850186395764, 0.3922706721579435, '77.3%'),
#   Text(0.3013616219086602, -0.5188267271841166, '12.1%'),
#   Text(0.5563582380203009, -0.2246453003891828, '8.9%'),
#   Text(0.5984126033171892, -0.0436160084274623, '1.0%'),
#   Text(0.5998677240628653, -0.012598159692515537, '0.7%')])

# %%
plt.subplot(1,2,1)
plt.xticks(rotation=-45)
sns.countplot(data['market_segment'])
plt.subplot(1,2,2)
sns.countplot(data['distribution_channel'])
# Out:
# <AxesSubplot:xlabel='distribution_channel', ylabel='count'>

# %%
plt.pie(data['is_repeated_guest'].value_counts(),labels=[0,1],autopct='%.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x181e05dacd0>,
# ...
#  [Text(-1.09447652566627, 0.11009602520295811, '0'),
#   Text(1.0944765295317447, -0.11009598677585064, '1')],
#  [Text(-0.5969871958179654, 0.060052377383431686, '96.8%'),
#   Text(0.5969871979264061, -0.060052356423191254, '3.2%')])

# %%
sns.countplot(data['previous_cancellations'],palette='Paired')
# Out:
# <AxesSubplot:xlabel='previous_cancellations', ylabel='count'>

# %%
plt.subplot(1,2,1)
plt.pie(data['reserved_room_type'].value_counts(),labels=['A','D','E','F','G','B','C','H','P','L'] ,autopct='%.1f%%')
plt.subplot(1,2,2)
plt.pie(data['assigned_room_type'].value_counts(),labels=['A','D','E','F','G','C','B','H','I','K','P','L'] ,autopct='%.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x181e0985940>,
# ...
#  [Text(-0.4057764854463065, 1.0224213631663042, 'A'),
#   Text(-0.16313834445947992, -1.0878354106054005, 'D'),
#   Text(0.7276882718132758, -0.8249059213421905, 'E'),
#   Text(0.9413092242472945, -0.5691545873898909, 'F'),
#   Text(1.0223678978281276, -0.405911174384859, 'G'),
#   Text(1.0662729112673477, -0.2702999790925912, 'C'),
#   Text(1.0908801740289253, -0.14135220518485692, 'B'),
#   Text(1.0984433591432838, -0.05849945943356209, 'H'),
#   Text(1.0996584861148735, -0.027408281878743383, 'I'),
#   Text(1.0999645727542142, -0.008828288941759512, 'K'),
#   Text(1.099999925307374, -0.0004053686863436951, 'P'),
#   Text(1.0999999996155416, -2.908278826855386e-05, 'L')],
#  [Text(-0.22133262842525808, 0.5576843799088931, '62.0%'),
#   Text(-0.08898455152335268, -0.5933647694211275, '21.2%'),
#   Text(0.396920875534514, -0.4499486843684675, '6.5%'),
#   Text(0.5134413950439787, -0.31044795675812226, '3.1%'),
# ...

# %%
sns.countplot(data['booking_changes'],palette='Paired')
# Out:
# <AxesSubplot:xlabel='booking_changes', ylabel='count'>

# %%
plt.pie(data['deposit_type'].value_counts(),labels=['No Deposit','Non Refund','Refundable'],autopct='%.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x181e0ae1fd0>,
# ...
#  [Text(-1.0181924325401428, 0.4162741528343872, 'No Deposit'),
#   Text(1.0164087119406244, -0.4206106635490841, 'Non Refund'),
#   Text(1.0999900062128796, -0.004688947833933911, 'Refundable')],
#  [Text(-0.5553776904764415, 0.2270586288187566, '87.6%'),
#   Text(0.5544047519676133, -0.2294239982995004, '12.2%'),
#   Text(0.5999945488433888, -0.002557607909418497, '0.1%')])

# %%
plt.pie(data['customer_type'].value_counts(),labels=['Transient','Transient-Party','Contract','Group'],autopct='%.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x181de74d340>,
# ...
#  [Text(-0.7792590652236177, 0.7763731765503068, 'Transient'),
#   Text(0.6786054633474156, -0.8657335762895185, 'Transient-Party'),
#   Text(1.0895997419764234, -0.15090527586838032, 'Contract'),
#   Text(1.099873215166035, -0.01670061556735508, 'Group')],
#  [Text(-0.4250503992128823, 0.4234762781183491, '75.1%'),
#   Text(0.37014843455313573, -0.47221831433973727, '21.0%'),
#   Text(0.5943271319871399, -0.08231196865548016, '3.4%'),
#   Text(0.5999308446360191, -0.009109426673102772, '0.5%')])

# %%
sns.distplot(data['adr'],color='navy')
# Out:
# <AxesSubplot:xlabel='adr', ylabel='Density'>

# %%
sns.countplot(data['required_car_parking_spaces'],palette='Paired')
# Out:
# <AxesSubplot:xlabel='required_car_parking_spaces', ylabel='count'>

# %%
sns.countplot(data['reservation_status'],palette='Paired')
# Out:
# <AxesSubplot:xlabel='reservation_status', ylabel='count'>
